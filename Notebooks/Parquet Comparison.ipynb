# %%
import pandas as pd
import os

data_directory = "/nfs/workspace/data/ssi/preprocessing"

# %%
combined_directory = os.path.join(data_directory, "03-combined")

# %%
combined_files= [os.path.join(combined_directory, filename) for filename in os.listdir(combined_directory)]
combined_files
# Out:
# ['/nfs/workspace/data/ssi/preprocessing/03-combined/receipts_ah_202301.parquet',
#  '/nfs/workspace/data/ssi/preprocessing/03-combined/ssi_plus_revenue.parquet',
#  '/nfs/workspace/data/ssi/preprocessing/03-combined/receipts_plus_202201_Prd.parquet',
#  '/nfs/workspace/data/ssi/preprocessing/03-combined/ssi_ah_revenue.parquet',
#  '/nfs/workspace/data/ssi/preprocessing/03-combined/ssi_lidl_revenue.parquet']

# %%
plus_df = pd.read_parquet(combined_files[1], engine="pyarrow")
plus_df.head()
# Out:
#   bg_number   month coicop_number coicop_name isba_number isba_name  \
# 0    901027  202107         11110       Rijst    11110701     Rijst
# 1    901027  202107         11110       Rijst    11110701     Rijst
# 2    901027  202107         11110       Rijst    11110701     Rijst
# 3    901027  202107         11110       Rijst    11110701     Rijst
# 4    901027  202107         11110       Rijst    11110701     Rijst
#
#   esba_number    esba_name    rep_id     ean_number           ean_name  \
# 0        3711  Witte rijst  43675579  2270950000000  ## BIO TOVERRIJST
# 1        3711  Witte rijst  43896123  2271870000000   ## SNELKOOKRIJST
# 2        3711  Witte rijst  43259183  2271940000000   ## SNELKOOKRIJST
# 3        3711  Witte rijst  26248778  2272590000000           ## RIJST
# 4        3711  Witte rijst  43675979  2274280000000  ## BIO TOVERRIJST
#
#    revenue  amount
# 0     5.81     7.0
# 1     1.20     2.0
# 2     1.20     2.0
# 3    13.53    11.0
# 4     3.32     4.0

# %%
len(plus_df)
# Out:
# 5817129

# %%
plus_df.describe(include="all")
# Out:
#        bg_number    month coicop_number coicop_name isba_number  \
# count    5817129  5817129       5817129     5817129     5817129
# unique         1       26            84          84         153
# top       901027   202212        999999    Onbekend   999999701
# freq     5817129   252870        708262      708262      702352
# mean         NaN      NaN           NaN         NaN         NaN
# std          NaN      NaN           NaN         NaN         NaN
# min          NaN      NaN           NaN         NaN         NaN
# 25%          NaN      NaN           NaN         NaN         NaN
# 50%          NaN      NaN           NaN         NaN         NaN
# 75%          NaN      NaN           NaN         NaN         NaN
# max          NaN      NaN           NaN         NaN         NaN
#
#                isba_name esba_number esba_name   rep_id     ean_number  \
# count            5817129     5817129   5817129  5817129        5817129
# unique               151        1302      1132   775661         160335
# top     Niet in te delen        5460    Overig  9532720  2270010000000
# freq              702352       90795     96617       26           4938
# mean                 NaN         NaN       NaN      NaN            NaN
# std                  NaN         NaN       NaN      NaN            NaN
# min                  NaN         NaN       NaN      NaN            NaN
# 25%                  NaN         NaN       NaN      NaN            NaN
# 50%                  NaN         NaN       NaN      NaN            NaN
# 75%                  NaN         NaN       NaN      NaN            NaN
# max                  NaN         NaN       NaN      NaN            NaN
#
#                ean_name       revenue        amount
# count           5817129  5.817129e+06  5.817129e+06
# unique           342340           NaN           NaN
# top     ## RUNDERGEHAKT           NaN           NaN
# freq              11959           NaN           NaN
# mean                NaN  1.232020e+03  6.733363e+02
# std                 NaN  1.149430e+04  8.771138e+04
# min                 NaN  1.000000e-02  0.000000e+00
# 25%                 NaN  3.590000e+00  2.000000e+00
# 50%                 NaN  1.144000e+01  4.000000e+00
# 75%                 NaN  5.957000e+01  2.000000e+01
# max                 NaN  2.177922e+06  8.644341e+07

# %%
lidl_df = pd.read_parquet(combined_files[-1], engine="pyarrow")
lidl_df.head()
# Out:
#   bg_number   month coicop_number coicop_name isba_number isba_name  \
# 0    908515  201801         11110       Rijst    11110901     Rijst
# 1    908515  201801         11110       Rijst    11110901     Rijst
# 2    908515  201801         11110       Rijst    11110901     Rijst
# 3    908515  201801         11110       Rijst    11110901     Rijst
# 4    908515  201801         11110       Rijst    11110901     Rijst
#
#   esba_number                                esba_name   rep_id ean_number  \
# 0       47_40  Grund-/Nähr-/Hilfsmittel/Frühstück_Reis  3185518    92775.0
# 1       47_40  Grund-/Nähr-/Hilfsmittel/Frühstück_Reis  3183385    22571.0
# 2       47_40  Grund-/Nähr-/Hilfsmittel/Frühstück_Reis  3183851    51009.0
# 3       47_40  Grund-/Nähr-/Hilfsmittel/Frühstück_Reis  3183852    51010.0
# 4       47_40  Grund-/Nähr-/Hilfsmittel/Frühstück_Reis  3183945    55571.0
#
#                          ean_name        revenue    amount
# 0                     Sushi rijst       0.990000       1.0
# 1   Italiaanse Risotto gesorteerd    4150.209961    2565.0
# 2           Rijst zilvervlies 1kg  169094.890625  121651.0
# 3                   Rijst wit 1kg   78635.203125   66080.0
# 4  Traditionele basmati rijst XXL  473773.781250   67783.0

# %%
len(lidl_df)
# Out:
# 414647

# %%
lidl_df.describe(include="all")
# Out:
#        bg_number   month coicop_number coicop_name isba_number isba_name  \
# count     414647  414647        414647      414647      414647    414647
# unique         1      68            83          83          84        83
# top       908515  202005        999999    Onbekend   999999701  onbekend
# freq      414647    7956         82275       74475       82275     82275
# mean         NaN     NaN           NaN         NaN         NaN       NaN
# std          NaN     NaN           NaN         NaN         NaN       NaN
# min          NaN     NaN           NaN         NaN         NaN       NaN
# 25%          NaN     NaN           NaN         NaN         NaN       NaN
# 50%          NaN     NaN           NaN         NaN         NaN       NaN
# 75%          NaN     NaN           NaN         NaN         NaN       NaN
# max          NaN     NaN           NaN         NaN         NaN       NaN
#
#        esba_number                      esba_name   rep_id ean_number  \
# count       414647                         414647   414647     414647
# unique         835                           1497    41096      40674
# top          70_10  Gebäck/Knabberwaren_Süßgebäck  3183644        nan
# freq          8258                           7546       56        390
# mean           NaN                            NaN      NaN        NaN
# std            NaN                            NaN      NaN        NaN
# min            NaN                            NaN      NaN        NaN
# 25%            NaN                            NaN      NaN        NaN
# 50%            NaN                            NaN      NaN        NaN
# 75%            NaN                            NaN      NaN        NaN
# max            NaN                            NaN      NaN        NaN
#
#        ean_name       revenue        amount
# count    414647  4.146470e+05  4.146470e+05
# unique    31751           NaN           NaN
# top        Jurk           NaN           NaN
# freq        644           NaN           NaN
# mean        NaN  6.811138e+04  4.647959e+04
# std         NaN  2.125459e+05  2.107504e+05
# min         NaN  1.000000e-02  1.000000e-03
# 25%         NaN  1.720000e+02  4.200000e+01
# 50%         NaN  1.180902e+04  3.633000e+03
# 75%         NaN  7.201410e+04  3.969900e+04
# max         NaN  1.800737e+07  2.198353e+07

# %%
ah_df = pd.read_parquet(combined_files[-2], engine="pyarrow")
ah_df.head()
# Out:
#   bg_number   month coicop_number coicop_name isba_number isba_name  \
# 0    470111  202107         11110       Rijst   011110701     Rijst
# 1    470111  202107         11110       Rijst   011110701     Rijst
# 2    470111  202107         11110       Rijst   011110701     Rijst
# 3    470111  202107         11110       Rijst   011110701     Rijst
# 4    470111  202107         11110       Rijst   011110701     Rijst
#
#   esba_number              esba_name   rep_id     ean_number  \
# 0      181400  grootverpakking rijst  4926783  6803573320186
# 1      181400  grootverpakking rijst  4922145  8715071077050
# 2      181400  grootverpakking rijst  4933687  8908004963111
# 3      181400  grootverpakking rijst  5006102  8908004963135
# 4      181400  grootverpakking rijst  5006103  8908004963210
#
#                   ean_name      revenue  amount
# 0      alesie pandan rijst  6625.299805  3408.0
# 1  unirice longgrain rijst  1328.479980   432.0
# 2      mehnat basmati rice  3599.879883   664.0
# 3      mehnat basmati rice  8165.569824   708.0
# 4      mehnat basmati rice    92.629997     8.0

# %%
len(ah_df)
# Out:
# 2949737

# %%
ah_df.describe(include="all")
# Out:
#        bg_number    month coicop_number coicop_name isba_number  \
# count    2949737  2949737       2949737     2949737     2949737
# unique         3       30           104         104         550
# top       470112   202312        999999    Onbekend  9999992201
# freq     1557462   103358        775911      775911      270310
# mean         NaN      NaN           NaN         NaN         NaN
# std          NaN      NaN           NaN         NaN         NaN
# min          NaN      NaN           NaN         NaN         NaN
# 25%          NaN      NaN           NaN         NaN         NaN
# 50%          NaN      NaN           NaN         NaN         NaN
# 75%          NaN      NaN           NaN         NaN         NaN
# max          NaN      NaN           NaN         NaN         NaN
#
#                   isba_name esba_number esba_name   rep_id     ean_number  \
# count               2949737     2949737   2949737  2949737        2949737
# unique                  377        3175      2639   231902         136564
# top     Divers/buiten scope           0  ONBEKEND  4937245  8710400653721
# freq                 530920      419500    419500       30            120
# mean                    NaN         NaN       NaN      NaN            NaN
# std                     NaN         NaN       NaN      NaN            NaN
# min                     NaN         NaN       NaN      NaN            NaN
# 25%                     NaN         NaN       NaN      NaN            NaN
# 50%                     NaN         NaN       NaN      NaN            NaN
# 75%                     NaN         NaN       NaN      NaN            NaN
# max                     NaN         NaN       NaN      NaN            NaN
#
#               ean_name       revenue        amount
# count          2949737  2.949737e+06  2.949737e+06
# unique           70960           NaN           NaN
# top     LOKAAL ARTIKEL           NaN           NaN
# freq            419479           NaN           NaN
# mean               NaN  1.344192e+04  6.072181e+03
# std                NaN  6.178699e+04  3.230076e+04
# min                NaN  1.000000e-02  1.000000e+00
# 25%                NaN  3.981000e+01  1.100000e+01
# 50%                NaN  6.813300e+02  1.790000e+02
# 75%                NaN  7.572620e+03  2.864000e+03
# max                NaN  1.298175e+07  4.902576e+06

# %% [markdown]
# # Preprocessed

# %%
preprocessed_directory = os.path.join(data_directory, "04-preprocessed")

# %%
preprocessed_files = [os.path.join(preprocessed_directory, filename) for filename in os.listdir(preprocessed_directory)]
preprocessed_files
# Out:
# ['/nfs/workspace/data/ssi/preprocessing/04-preprocessed/receipts_ah_202301.parquet',
#  '/nfs/workspace/data/ssi/preprocessing/04-preprocessed/ssi_plus_revenue.parquet',
#  '/nfs/workspace/data/ssi/preprocessing/04-preprocessed/receipts_plus_202201_Prd.parquet',
#  '/nfs/workspace/data/ssi/preprocessing/04-preprocessed/ssi_ah_revenue.parquet',
#  '/nfs/workspace/data/ssi/preprocessing/04-preprocessed/ssi_lidl_revenue.parquet']

# %%
plus_df = pd.read_parquet(preprocessed_files[1], engine="pyarrow")
plus_df.head()
# Out:
#   store_id year_month coicop_number coicop_name isba_number isba_name  \
# 0   901027     202107        011110       Rijst    11110701     Rijst
# 1   901027     202107        011110       Rijst    11110701     Rijst
# 2   901027     202107        011110       Rijst    11110701     Rijst
# 3   901027     202107        011110       Rijst    11110701     Rijst
# 4   901027     202107        011110       Rijst    11110701     Rijst
#
#   esba_number    esba_name    rep_id     ean_number           ean_name  \
# 0        3711  Witte rijst  43675579  2270950000000  ## BIO TOVERRIJST
# 1        3711  Witte rijst  43896123  2271870000000   ## SNELKOOKRIJST
# 2        3711  Witte rijst  43259183  2271940000000   ## SNELKOOKRIJST
# 3        3711  Witte rijst  26248778  2272590000000           ## RIJST
# 4        3711  Witte rijst  43675979  2274280000000  ## BIO TOVERRIJST
#
#    revenue  amount  year month coicop_level_1 coicop_level_2 coicop_level_3  \
# 0     5.81     7.0  2021    07             01            011           0111
# 1     1.20     2.0  2021    07             01            011           0111
# 2     1.20     2.0  2021    07             01            011           0111
# 3    13.53    11.0  2021    07             01            011           0111
# 4     3.32     4.0  2021    07             01            011           0111
#
#   coicop_level_4
# 0          01111
# 1          01111
# 2          01111
# 3          01111
# 4          01111

# %%
len(plus_df)
# Out:
# 5817129

# %%
plus_df.describe(include="all")
# Out:
#        store_id year_month coicop_number coicop_name isba_number  \
# count   5817129    5817129       5817129     5817129     5817129
# unique        1         26            84          84         153
# top      901027     202212        999999    Onbekend   999999701
# freq    5817129     252870        708262      708262      702352
# mean        NaN        NaN           NaN         NaN         NaN
# std         NaN        NaN           NaN         NaN         NaN
# min         NaN        NaN           NaN         NaN         NaN
# 25%         NaN        NaN           NaN         NaN         NaN
# 50%         NaN        NaN           NaN         NaN         NaN
# 75%         NaN        NaN           NaN         NaN         NaN
# max         NaN        NaN           NaN         NaN         NaN
#
#                isba_name esba_number esba_name   rep_id     ean_number  \
# count            5817129     5817129   5817129  5817129        5817129
# unique               151        1302      1132   775661         160335
# top     Niet in te delen        5460    Overig  9532720  2270010000000
# freq              702352       90795     96617       26           4938
# mean                 NaN         NaN       NaN      NaN            NaN
# std                  NaN         NaN       NaN      NaN            NaN
# min                  NaN         NaN       NaN      NaN            NaN
# 25%                  NaN         NaN       NaN      NaN            NaN
# 50%                  NaN         NaN       NaN      NaN            NaN
# 75%                  NaN         NaN       NaN      NaN            NaN
# max                  NaN         NaN       NaN      NaN            NaN
#
#                ean_name       revenue        amount     year    month  \
# count           5817129  5.817129e+06  5.817129e+06  5817129  5817129
# unique           342340           NaN           NaN        3       12
# top     ## RUNDERGEHAKT           NaN           NaN     2022       07
# freq              11959           NaN           NaN  2630185   717889
# mean                NaN  1.232020e+03  6.733363e+02      NaN      NaN
# std                 NaN  1.149430e+04  8.771138e+04      NaN      NaN
# min                 NaN  1.000000e-02  0.000000e+00      NaN      NaN
# 25%                 NaN  3.590000e+00  2.000000e+00      NaN      NaN
# 50%                 NaN  1.144000e+01  4.000000e+00      NaN      NaN
# 75%                 NaN  5.957000e+01  2.000000e+01      NaN      NaN
# max                 NaN  2.177922e+06  8.644341e+07      NaN      NaN
#
#        coicop_level_1 coicop_level_2 coicop_level_3 coicop_level_4
# count         5817129        5817129        5817129        5817129
# unique              9             19             37             84
# top                01            011           0112          99999
# freq          4367680        4211493        1163926         708262
# mean              NaN            NaN            NaN            NaN
# std               NaN            NaN            NaN            NaN
# min               NaN            NaN            NaN            NaN
# 25%               NaN            NaN            NaN            NaN
# 50%               NaN            NaN            NaN            NaN
# 75%               NaN            NaN            NaN            NaN
# max               NaN            NaN            NaN            NaN

# %%
lidl_df = pd.read_parquet(preprocessed_files[-1], engine="pyarrow")
lidl_df.head()
# Out:
#   store_id year_month coicop_number coicop_name isba_number isba_name  \
# 0   908515     201801        011110       Rijst    11110901     Rijst
# 1   908515     201801        011110       Rijst    11110901     Rijst
# 2   908515     201801        011110       Rijst    11110901     Rijst
# 3   908515     201801        011110       Rijst    11110901     Rijst
# 4   908515     201801        011110       Rijst    11110901     Rijst
#
#   esba_number                                esba_name   rep_id ean_number  \
# 0       47_40  Grund-/Nähr-/Hilfsmittel/Frühstück_Reis  3185518    92775.0
# 1       47_40  Grund-/Nähr-/Hilfsmittel/Frühstück_Reis  3183385    22571.0
# 2       47_40  Grund-/Nähr-/Hilfsmittel/Frühstück_Reis  3183851    51009.0
# 3       47_40  Grund-/Nähr-/Hilfsmittel/Frühstück_Reis  3183852    51010.0
# 4       47_40  Grund-/Nähr-/Hilfsmittel/Frühstück_Reis  3183945    55571.0
#
#                          ean_name        revenue    amount  year month  \
# 0                     Sushi rijst       0.990000       1.0  2018    01
# 1   Italiaanse Risotto gesorteerd    4150.209961    2565.0  2018    01
# 2           Rijst zilvervlies 1kg  169094.890625  121651.0  2018    01
# 3                   Rijst wit 1kg   78635.203125   66080.0  2018    01
# 4  Traditionele basmati rijst XXL  473773.781250   67783.0  2018    01
#
#   coicop_level_1 coicop_level_2 coicop_level_3 coicop_level_4
# 0             01            011           0111          01111
# 1             01            011           0111          01111
# 2             01            011           0111          01111
# 3             01            011           0111          01111
# 4             01            011           0111          01111

# %%
len(lidl_df)
# Out:
# 413280

# %%
lidl_df.describe(include="all")
# Out:
#        store_id year_month coicop_number coicop_name isba_number isba_name  \
# count    413280     413280        413280      413280      413280    413280
# unique        1         68            82          83          83        82
# top      908515     202008        999999    Onbekend   999999701  onbekend
# freq     413280       7824         82275       73108       82275     82275
# mean        NaN        NaN           NaN         NaN         NaN       NaN
# std         NaN        NaN           NaN         NaN         NaN       NaN
# min         NaN        NaN           NaN         NaN         NaN       NaN
# 25%         NaN        NaN           NaN         NaN         NaN       NaN
# 50%         NaN        NaN           NaN         NaN         NaN       NaN
# 75%         NaN        NaN           NaN         NaN         NaN       NaN
# max         NaN        NaN           NaN         NaN         NaN       NaN
#
#        esba_number                      esba_name   rep_id ean_number  \
# count       413280                         413280   413280     413280
# unique         834                           1497    41037      40659
# top          70_10  Gebäck/Knabberwaren_Süßgebäck  3182703     1493.0
# freq          8258                           7546       56         41
# mean           NaN                            NaN      NaN        NaN
# std            NaN                            NaN      NaN        NaN
# min            NaN                            NaN      NaN        NaN
# 25%            NaN                            NaN      NaN        NaN
# 50%            NaN                            NaN      NaN        NaN
# 75%            NaN                            NaN      NaN        NaN
# max            NaN                            NaN      NaN        NaN
#
#        ean_name       revenue        amount    year   month coicop_level_1  \
# count    413280  4.132800e+05  4.132800e+05  413280  413280         413280
# unique    31748           NaN           NaN       6      12              8
# top        Jurk           NaN           NaN    2020      05             01
# freq        644           NaN           NaN   89545   36916         196848
# mean        NaN  6.830840e+04  4.662425e+04     NaN     NaN            NaN
# std         NaN  2.128613e+05  2.110821e+05     NaN     NaN            NaN
# min         NaN  1.000000e-02  1.000000e-03     NaN     NaN            NaN
# 25%         NaN  1.745650e+02  4.200000e+01     NaN     NaN            NaN
# 50%         NaN  1.200731e+04  3.706500e+03     NaN     NaN            NaN
# 75%         NaN  7.231555e+04  3.987925e+04     NaN     NaN            NaN
# max         NaN  1.800737e+07  2.198353e+07     NaN     NaN            NaN
#
#        coicop_level_2 coicop_level_3 coicop_level_4
# count          413280         413280         413280
# unique             15             35             82
# top               011           9999          99999
# freq           177152          82275          82275
# mean              NaN            NaN            NaN
# std               NaN            NaN            NaN
# min               NaN            NaN            NaN
# 25%               NaN            NaN            NaN
# 50%               NaN            NaN            NaN
# 75%               NaN            NaN            NaN
# max               NaN            NaN            NaN

# %%
ah_df = pd.read_parquet(preprocessed_files[-2], engine="pyarrow")
ah_df.head()
# Out:
#   store_id year_month coicop_number coicop_name isba_number isba_name  \
# 0   470111     202107        011110       Rijst   011110701     Rijst
# 1   470111     202107        011110       Rijst   011110701     Rijst
# 2   470111     202107        011110       Rijst   011110701     Rijst
# 3   470111     202107        011110       Rijst   011110701     Rijst
# 4   470111     202107        011110       Rijst   011110701     Rijst
#
#   esba_number              esba_name   rep_id     ean_number  \
# 0      181400  grootverpakking rijst  4926783  6803573320186
# 1      181400  grootverpakking rijst  4922145  8715071077050
# 2      181400  grootverpakking rijst  4933687  8908004963111
# 3      181400  grootverpakking rijst  5006102  8908004963135
# 4      181400  grootverpakking rijst  5006103  8908004963210
#
#                   ean_name      revenue  amount  year month coicop_level_1  \
# 0      alesie pandan rijst  6625.299805  3408.0  2021    07             01
# 1  unirice longgrain rijst  1328.479980   432.0  2021    07             01
# 2      mehnat basmati rice  3599.879883   664.0  2021    07             01
# 3      mehnat basmati rice  8165.569824   708.0  2021    07             01
# 4      mehnat basmati rice    92.629997     8.0  2021    07             01
#
#   coicop_level_2 coicop_level_3 coicop_level_4
# 0            011           0111          01111
# 1            011           0111          01111
# 2            011           0111          01111
# 3            011           0111          01111
# 4            011           0111          01111

# %%
len(ah_df)
# Out:
# 2949737

# %%
ah_df.describe(include="all")
# Out:
#        store_id year_month coicop_number coicop_name isba_number  \
# count   2949737    2949737       2949737     2949737     2949737
# unique        3         30           104         104         550
# top      470112     202312        999999    Onbekend  9999992201
# freq    1557462     103358        775911      775911      270310
# mean        NaN        NaN           NaN         NaN         NaN
# std         NaN        NaN           NaN         NaN         NaN
# min         NaN        NaN           NaN         NaN         NaN
# 25%         NaN        NaN           NaN         NaN         NaN
# 50%         NaN        NaN           NaN         NaN         NaN
# 75%         NaN        NaN           NaN         NaN         NaN
# max         NaN        NaN           NaN         NaN         NaN
#
#                   isba_name esba_number esba_name   rep_id     ean_number  \
# count               2949737     2949737   2949737  2949737        2949737
# unique                  377        3175      2639   231902         136564
# top     Divers/buiten scope           0  ONBEKEND  4937245  8710400653721
# freq                 530920      419500    419500       30            120
# mean                    NaN         NaN       NaN      NaN            NaN
# std                     NaN         NaN       NaN      NaN            NaN
# min                     NaN         NaN       NaN      NaN            NaN
# 25%                     NaN         NaN       NaN      NaN            NaN
# 50%                     NaN         NaN       NaN      NaN            NaN
# 75%                     NaN         NaN       NaN      NaN            NaN
# max                     NaN         NaN       NaN      NaN            NaN
#
#               ean_name       revenue        amount     year    month  \
# count          2949737  2.949737e+06  2.949737e+06  2949737  2949737
# unique           70960           NaN           NaN        3       12
# top     LOKAAL ARTIKEL           NaN           NaN     2023       12
# freq            419479           NaN           NaN  1182808   306409
# mean               NaN  1.344192e+04  6.072181e+03      NaN      NaN
# std                NaN  6.178699e+04  3.230076e+04      NaN      NaN
# min                NaN  1.000000e-02  1.000000e+00      NaN      NaN
# 25%                NaN  3.981000e+01  1.100000e+01      NaN      NaN
# 50%                NaN  6.813300e+02  1.790000e+02      NaN      NaN
# 75%                NaN  7.572620e+03  2.864000e+03      NaN      NaN
# max                NaN  1.298175e+07  4.902576e+06      NaN      NaN
#
#        coicop_level_1 coicop_level_2 coicop_level_3 coicop_level_4
# count         2949737        2949737        2949737        2949737
# unique             10             17             36            104
# top                01            011           9999          99999
# freq          1099136         949053         775911         775911
# mean              NaN            NaN            NaN            NaN
# std               NaN            NaN            NaN            NaN
# min               NaN            NaN            NaN            NaN
# 25%               NaN            NaN            NaN            NaN
# 50%               NaN            NaN            NaN            NaN
# 75%               NaN            NaN            NaN            NaN
# max               NaN            NaN            NaN            NaN
